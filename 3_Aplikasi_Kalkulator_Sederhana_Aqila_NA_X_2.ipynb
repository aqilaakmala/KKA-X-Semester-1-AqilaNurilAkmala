# %% [markdown]
# <a href="https://colab.research.google.com/github/aqilaakmala/KKA-X-Semester-1-AqilaNurilAkmala/blob/main/3_Aplikasi_Kalkulator_Sederhana_Aqila_NA_X_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
panjang = int(input("Masukkan panjang dari persegi panjang (cm): "))
lebar = int(input("Masukkan lebar dari persegi panjang (cm): "))

luas = panjang * lebar

print(f"\nLuas dari persegi panjang yaitu {luas} cm^2")
# Out:
# Masukkan panjang dari persegi panjang (cm): 5
# Masukkan lebar dari persegi panjang (cm): 4
#
# Luas dari persegi panjang yaitu 20 cm^2

# %% [markdown]
# #Kalkulator Menghitung Volume Bangun Kerucut

# %%
r = int(input("masukkan jari-jari dari bangun kerucut (cm): "))
t = int(input("masukkan tinggi dari bangun kerucut (cm): "))

volume = 1/3 * 22/7 * r**2 * t

print(f"\nvolume dari bangun kerucut yaitu {volume} cm^3")
# Out:
# masukkan jari-jari dari bangun kerucut (cm): 7
# masukkan tinggi dari bangun kerucut (cm): 9
#
# volume dari bangun kerucut yaitu 462.0 cm^3
